# %%
mkdir data

# %%
module avail sra
# Out:
# --------------------------- /share/apps/modulefiles ----------------------------
#    sra-tools/2.10.9

# %%
module avail kallisto
# Out:
# --------------------------- /share/apps/modulefiles ----------------------------
#    kallisto/0.46.1

# %%
module avail salmon
# Out:
# --------------------------- /share/apps/modulefiles ----------------------------
#    salmon/0.8.0    salmon/1.4.0

# %%
module avail fastqc
# Out:
# --------------------------- /share/apps/modulefiles ----------------------------
#    fastqc/0.11.9

# %%
module avail trimmomatic
# Out:
# --------------------------- /share/apps/modulefiles ----------------------------
#    trimmomatic/0.36    trimmomatic/0.39

# %%
module purge

module load sra-tools/2.10.9
module load kallisto/0.46.1
module load salmon/1.4.0
module load fastqc/0.11.9
module load trimmomatic/0.39

# %%
## Retrieve RNA-seq data
## https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM1679648
## https://trace.ncbi.nlm.nih.gov/Traces/sra/?run=SRR2015713

cd data
fastq-dump --split-3 SRR2015713
# Out:
# Read 60054217 spots for SRR2015713
# Written 60054217 spots for SRR2015713

# %% [markdown]
# ## FastQC

# %%
fastqc SRR2015713_1.fastq SRR2015713_2.fastq
# Out:
# Started analysis of SRR2015713_1.fastq
# Approx 5% complete for SRR2015713_1.fastq
# Approx 10% complete for SRR2015713_1.fastq
# Approx 15% complete for SRR2015713_1.fastq
# Approx 20% complete for SRR2015713_1.fastq
# Approx 25% complete for SRR2015713_1.fastq
# Approx 30% complete for SRR2015713_1.fastq
# Approx 35% complete for SRR2015713_1.fastq
# Approx 40% complete for SRR2015713_1.fastq
# Approx 45% complete for SRR2015713_1.fastq
# Approx 50% complete for SRR2015713_1.fastq
# Approx 55% complete for SRR2015713_1.fastq
# Approx 60% complete for SRR2015713_1.fastq
# Approx 65% complete for SRR2015713_1.fastq
# Approx 70% complete for SRR2015713_1.fastq
# Approx 75% complete for SRR2015713_1.fastq
# Approx 80% complete for SRR2015713_1.fastq
# Approx 85% complete for SRR2015713_1.fastq
# Approx 90% complete for SRR2015713_1.fastq
# Approx 95% complete for SRR2015713_1.fastq
# Analysis complete for SRR2015713_1.fastq
# Started analysis of SRR2015713_2.fastq
# Approx 5% complete for SRR2015713_2.fastq
# Approx 10% complete for SRR2015713_2.fastq
# Approx 15% complete for SRR2015713_2.fastq
# Approx 20% complete for SRR2015713_2.fastq
# Approx 25% complete for SRR2015713_2.fastq
# Approx 30% complete for SRR2015713_2.fastq
# Approx 35% complete for SRR2015713_2.fastq
# Approx 40% complete for SRR2015713_2.fastq
# Approx 45% complete for SRR2015713_2.fastq
# Approx 50% complete for SRR2015713_2.fastq
# Approx 55% complete for SRR2015713_2.fastq
# Approx 60% complete for SRR2015713_2.fastq
# Approx 65% complete for SRR2015713_2.fastq
# Approx 70% complete for SRR2015713_2.fastq
# Approx 75% complete for SRR2015713_2.fastq
# Approx 80% complete for SRR2015713_2.fastq
# Approx 85% complete for SRR2015713_2.fastq
# Approx 90% complete for SRR2015713_2.fastq
# Approx 95% complete for SRR2015713_2.fastq
# Analysis complete for SRR2015713_2.fastq

# %%
## Retrieve human transcriptome
## https://useast.ensembl.org/info/data/ftp/index.html
cd ..
mkdir GRCh38
wget http://ftp.ensembl.org/pub/release-103/fasta/homo_sapiens/cdna/Homo_sapiens.GRCh38.cdna.all.fa.gz
wget http://ftp.ensembl.org/pub/release-103/fasta/homo_sapiens/ncrna/Homo_sapiens.GRCh38.ncrna.fa.gz

# %%
## Prepare full transcriptome (cDNA + ncRNA)
zcat Homo_sapiens.GRCh38.cdna.all.fa.gz > "Homo_sapiens.GRCh38.all.fa"
zcat Homo_sapiens.GRCh38.ncrna.fa.gz >> "Homo_sapiens.GRCh38.all.fa"

# %% [markdown]
# ## Using Kallisto: Indexing and alignment
#
# https://pachterlab.github.io/kallisto/manual

# %%
time kallisto index -i GRCh38 Homo_sapiens.GRCh38.all.fa
# Out:
# [build] loading fasta file Homo_sapiens.GRCh38.all.fa
# [build] k-mer length: 31
# [build] warning: clipped off poly-A tail (longer than 10)
#         from 1977 target sequences
# [build] warning: replaced 100008 non-ACGUT characters in the input sequence
#         with pseudorandom nucleotides
# [build] counting k-mers ... done.
# [build] building target de Bruijn graph ...  done
# [build] creating equivalence classes ...  done
# [build] target de Bruijn graph has 1538889 contigs and contains 142407578 k-mers
#
#
# real	6m57.983s
# user	6m45.349s
# sys	0m11.237s

# %%
cd ..
time kallisto quant -i GRCh38/GRCh38 \
                    -o result/kallisto \
                    data/SRR2015713_1.fastq data/SRR2015713_2.fastq
# Out:
# [quant] fragment length distribution will be estimated from the data
# [index] k-mer length: 31
# [index] number of targets: 255,044
# [index] number of k-mers: 142,407,578
# [index] number of equivalence classes: 1,039,961
# [quant] running in paired-end mode
# [quant] will process pair 1: data/SRR2015713_1.fastq
#                              data/SRR2015713_2.fastq
# [quant] finding pseudoalignments for the reads ... done
# [quant] processed 60,054,217 reads, 52,305,678 reads pseudoaligned
# [quant] estimated average fragment length: 166.922
# [   em] quantifying the abundances ... done
# [   em] the Expectation-Maximization algorithm ran for 1,489 rounds
#
#
# real	10m4.125s
# user	9m34.953s
# sys	0m27.287s

# %% [markdown]
# ## Using Salmon: Indexing and alignment
# https://salmon.readthedocs.io/en/latest/

# %%
cd GRCh38

# %%
time salmon index -t Homo_sapiens.GRCh38.all.fa \
                  -i GRCh38.salmon \
                  -k 31
# Out:
# Version Info: This is the most recent version of salmon.
# index ["GRCh38.salmon"] did not previously exist  . . . creating it
# [2021-03-07 21:36:43.708] [jLog] [warning] The salmon index is being built without any decoy sequences.  It is recommended that decoy sequence (either computed auxiliary decoy sequence or the genome of the organism) be provided during indexing. Further details can be found at https://salmon.readthedocs.io/en/latest/salmon.html#preparing-transcriptome-indices-mapping-based-mode.
# [2021-03-07 21:36:43.708] [jLog] [info] building index
# out : GRCh38.salmon
# [2021-03-07 21:36:45.459] [puff::index::jointLog] [info] Running fixFasta
#
# [Step 1 of 4] : counting k-mers
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000631435.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000415118.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000434970.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000448914.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632684.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632524.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633009.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000634070.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632963.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633030.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633765.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632619.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632968.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633159.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000631871.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633010.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632473.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000631884.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632859.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000631895.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000634154.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632609.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632911.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633504.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632304.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000632542.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633968.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000634085.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633353.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000631803.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000633210.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000604642.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000603326.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000604950.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000603077.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000605284.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000604446.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000603693.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000603935.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000604102.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000604838.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000439842.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390567.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000452198.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390569.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000437320.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390571.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390572.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000450276.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390574.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390575.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000431870.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390578.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000451044.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390580.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390581.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000431440.2], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390583.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390584.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390585.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000430425.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000454691.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390588.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000414852.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390590.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000390591.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.551] [puff::index::jointLog] [warning] Entry with header [ENST00000454908.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.601] [puff::index::jointLog] [warning] Entry with header [ENST00000629250.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.669] [puff::index::jointLog] [warning] Entry with header [ENST00000632054.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.729] [puff::index::jointLog] [warning] Entry with header [ENST00000437226.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.771] [puff::index::jointLog] [warning] Entry with header [ENST00000626807.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.971] [puff::index::jointLog] [warning] Entry with header [ENST00000417283.5], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:45.971] [puff::index::jointLog] [warning] Entry with header [ENST00000465958.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.171] [puff::index::jointLog] [warning] Entry with header [ENST00000632342.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.173] [puff::index::jointLog] [warning] Entry with header [ENST00000518246.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.383] [puff::index::jointLog] [warning] Entry with header [ENST00000603775.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.444] [puff::index::jointLog] [warning] Entry with header [ENST00000579054.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.517] [puff::index::jointLog] [warning] Entry with header [ENST00000473810.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.520] [puff::index::jointLog] [warning] Entry with header [ENST00000543745.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.571] [puff::index::jointLog] [warning] Entry with header [ENST00000573437.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.622] [puff::index::jointLog] [warning] Entry with header [ENST00000634174.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.689] [puff::index::jointLog] [warning] Entry with header [ENST00000626232.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.738] [puff::index::jointLog] [warning] Entry with header [ENST00000445788.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
# [2021-03-07 21:36:54.992] [puff::index::jointLog] [warning] Entry with header [ENST00000411692.1], had length less than equal to the k-mer length of 31 (perhaps after poly-A clipping)
#
# [2021-03-07 21:36:56.614] [puff::index::jointLog] [warning] Removed 14712 transcripts that were sequence duplicates of indexed transcripts.
# [2021-03-07 21:36:56.614] [puff::index::jointLog] [warning] If you wish to retain duplicate transcripts, please use the `--keepDuplicates` flag
# [2021-03-07 21:36:58.980] [puff::index::jointLog] [info] Replaced 100,008 non-ATCG nucleotides
# [2021-03-07 21:36:58.980] [puff::index::jointLog] [info] Clipped poly-A tails from 1,977 transcripts
# wrote 240285 cleaned references
# [2021-03-07 21:37:06.458] [puff::index::jointLog] [info] Filter size not provided; estimating from number of distinct k-mers
# [2021-03-07 21:37:10.289] [puff::index::jointLog] [info] ntHll estimated 140914689 distinct k-mers, setting filter size to 2^32
# Threads = 2
# Vertex length = 31
# Hash functions = 5
# Filter size = 4294967296
# Capacity = 2
# Files:
# GRCh38.salmon/ref_k31_fixed.fa
# --------------------------------------------------------------------------------
# Round 0, 0:4294967296
# Pass	Filling	Filtering
# 1	76	160
# 2	11	0
# True junctions count = 978373
# False junctions count = 243833
# Hash table size = 1222206
# Candidate marks count = 9585017
# --------------------------------------------------------------------------------
# Reallocating bifurcations time: 0
# True marks count: 9341760
# Edges construction time: 17
# --------------------------------------------------------------------------------
# Distinct junctions = 978373
#
# allowedIn: 18
# Max Junction ID: 1131143
# seen.size():9049153 kmerInfo.size():1131144
# approximateContigTotalLength: 100189362
# counters for complex kmers:
# (prec>1 & succ>1)=74249 | (succ>1 & isStart)=1182 | (prec>1 & isEnd)=1132 | (isStart & isEnd)=99
# contig count: 1488275 element count: 187055820 complex nodes: 76662
# # of ones in rank vector: 1488274
# [2021-03-07 21:42:04.185] [puff::index::jointLog] [info] Starting the Pufferfish indexing by reading the GFA binary file.
# [2021-03-07 21:42:04.185] [puff::index::jointLog] [info] Setting the index/BinaryGfa directory GRCh38.salmon
# size = 187055820
# -----------------------------------------
# | Loading contigs | Time = 25.531 ms
# -----------------------------------------
# size = 187055820
# -----------------------------------------
# | Loading contig boundaries | Time = 13.001 ms
# -----------------------------------------
# Number of ones: 1488274
# Number of ones per inventory item: 512
# Inventory entries filled: 2907
# 1488274
# [2021-03-07 21:42:04.527] [puff::index::jointLog] [info] Done wrapping the rank vector with a rank9sel structure.
# [2021-03-07 21:42:04.542] [puff::index::jointLog] [info] contig count for validation: 1,488,274
# [2021-03-07 21:42:05.011] [puff::index::jointLog] [info] Total # of Contigs : 1,488,274
# [2021-03-07 21:42:05.011] [puff::index::jointLog] [info] Total # of numerical Contigs : 1,488,274
# [2021-03-07 21:42:05.113] [puff::index::jointLog] [info] Total # of contig vec entries: 9,412,960
# [2021-03-07 21:42:05.113] [puff::index::jointLog] [info] bits per offset entry 24
# [2021-03-07 21:42:05.458] [puff::index::jointLog] [info] Done constructing the contig vector. 1488275
# [2021-03-07 21:42:11.256] [puff::index::jointLog] [info] # segments = 1,488,274
# [2021-03-07 21:42:11.256] [puff::index::jointLog] [info] total length = 187,055,820
# [2021-03-07 21:42:11.344] [puff::index::jointLog] [info] Reading the reference files ...
# [2021-03-07 21:42:14.898] [puff::index::jointLog] [info] positional integer width = 28
# [2021-03-07 21:42:14.898] [puff::index::jointLog] [info] seqSize = 187,055,820
# [2021-03-07 21:42:14.898] [puff::index::jointLog] [info] rankSize = 187,055,820
# [2021-03-07 21:42:14.898] [puff::index::jointLog] [info] edgeVecSize = 0
# [2021-03-07 21:42:14.898] [puff::index::jointLog] [info] num keys = 142,407,600
# for info, total work write each  : 2.331    total work inram from level 3 : 4.322  total work raw : 25.000
# [Building BooPHF]  99.9 %   elapsed:   0 min 18 sec   remaining:   0 min 0  sec
# Bitarray       746175808  bits (100.00 %)   (array + ranks )
# final hash             0  bits (0.00 %) (nb in final hash 0)
# [2021-03-07 21:43:00.194] [puff::index::jointLog] [info] mphf size = 88.9511 MB
# [2021-03-07 21:43:00.430] [puff::index::jointLog] [info] chunk size = 93,527,910
# [2021-03-07 21:43:00.430] [puff::index::jointLog] [info] chunk 0 = [0, 93,527,919)
# [2021-03-07 21:43:00.430] [puff::index::jointLog] [info] chunk 1 = [93,527,919, 187,055,790)
# [2021-03-07 21:43:14.856] [puff::index::jointLog] [info] finished populating pos vector
# [2021-03-07 21:43:14.856] [puff::index::jointLog] [info] writing index components
# [2021-03-07 21:43:20.740] [puff::index::jointLog] [info] finished writing dense pufferfish index
# [2021-03-07 21:43:22.623] [jLog] [info] done building index
#
# real	6m41.331s
# user	10m4.416s
# sys	0m9.090s

# %%
cd ..
mkdir result/salmon
time salmon quant -i GRCh38/GRCh38.salmon \
                  --libType A \
                  -1 data/SRR2015713_1.fastq \
                  -2 data/SRR2015713_2.fastq \
                  -o result/salmon
# Out:
# Version Info: This is the most recent version of salmon.
# ### salmon (selective-alignment-based) v1.4.0
# ### [ program ] => salmon
# ### [ command ] => quant
# ### [ index ] => { GRCh38/GRCh38.salmon }
# ### [ libType ] => { A }
# ### [ mates1 ] => { data/SRR2015713_1.fastq }
# ### [ mates2 ] => { data/SRR2015713_2.fastq }
# ### [ output ] => { result/salmon }
# Logs will be written to result/salmon/logs
# [2021-03-07 22:11:44.750] [jointLog] [info] setting maxHashResizeThreads to 48
# [2021-03-07 22:11:44.750] [jointLog] [info] Fragment incompatibility prior below threshold.  Incompatible fragments will be ignored.
# [2021-03-07 22:11:44.750] [jointLog] [info] Usage of --validateMappings implies use of minScoreFraction. Since not explicitly specified, it is being set to 0.65
# [2021-03-07 22:11:44.750] [jointLog] [info] Setting consensusSlack to selective-alignment default of 0.35.
# [2021-03-07 22:11:44.750] [jointLog] [info] parsing read library format
# [2021-03-07 22:11:44.750] [jointLog] [info] There is 1 library.
# [2021-03-07 22:11:44.824] [jointLog] [info] Loading pufferfish index
# [2021-03-07 22:11:44.824] [jointLog] [info] Loading dense pufferfish index.
# -----------------------------------------
# | Loading contig table | Time = 323.2 ms
# -----------------------------------------
# size = 1488275
# -----------------------------------------
# | Loading contig offsets | Time = 23.918 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference lengths | Time = 16.785 ms
# -----------------------------------------
# -----------------------------------------
# | Loading mphf table | Time = 156.98 ms
# -----------------------------------------
# size = 187055820
# Number of ones: 1488274
# Number of ones per inventory item: 512
# Inventory entries filled: 2907
# -----------------------------------------
# | Loading contig boundaries | Time = 357.96 ms
# -----------------------------------------
# size = 187055820
# -----------------------------------------
# | Loading sequence | Time = 119.59 ms
# -----------------------------------------
# size = 142407600
# -----------------------------------------
# | Loading positions | Time = 369.86 ms
# -----------------------------------------
# size = 394746297
# -----------------------------------------
# | Loading reference sequence | Time = 166.82 ms
# -----------------------------------------
# -----------------------------------------
# | Loading reference accumulative lengths | Time = 32.299 ms
# -----------------------------------------
# [2021-03-07 22:11:46.409] [jointLog] [info] done
# [2021-03-07 22:11:46.410] [jointLog] [info] Index contained 240,332 targets
# [2021-03-07 22:11:46.498] [jointLog] [info] Number of decoys : 0
#
#
#
#
# [2021-03-07 22:11:47.934] [jointLog] [info] Automatically detected most likely library type as IU
#
# processed 500,000 fragments
# processed 1,000,000 fragments
# processed 1,500,000 fragments
# processed 2,000,000 fragments
# processed 2,500,000 fragments
# processed 3,000,000 fragments
# processed 3,500,000 fragments
# processed 4,000,000 fragments
# processed 4,500,000 fragments
# processed 5,000,000 fragments
# processed 5,500,000 fragments
# processed 6,000,000 fragments
# processed 6,500,000 fragments
# processed 7,000,000 fragments
# processed 7,500,000 fragments
# processed 8,000,000 fragments
# processed 8,500,000 fragments
# processed 9,000,000 fragments
# processed 9,500,000 fragments
# processed 10,000,000 fragments
# processed 10,500,000 fragments
# processed 11,000,000 fragments
# processed 11,500,000 fragments
# processed 12,000,000 fragments
# processed 12,500,000 fragments
# processed 13,000,000 fragments
# processed 13,500,000 fragments
# processed 14,000,000 fragments
# processed 14,500,000 fragments
# processed 15,000,000 fragments
# processed 15,500,000 fragments
# processed 16,000,000 fragments
# processed 16,500,000 fragments
# processed 17,000,000 fragments
# processed 17,500,000 fragments
# processed 18,000,000 fragments
# processed 18,500,000 fragments
# processed 19,000,000 fragments
# processed 19,500,000 fragments
# processed 20,000,000 fragments
# processed 20,500,000 fragments
# processed 21,000,000 fragments
# processed 21,500,000 fragments
# processed 22,000,000 fragments
# processed 22,500,000 fragments
# processed 23,000,000 fragments
# processed 23,500,000 fragments
# processed 24,000,000 fragments
# processed 24,500,000 fragments
# processed 25,000,000 fragments
# processed 25,500,000 fragments
# processed 26,000,000 fragments
# processed 26,500,000 fragments
# processed 27,000,000 fragments
# processed 27,500,000 fragments
# processed 28,000,000 fragments
# processed 28,500,000 fragments
# processed 29,000,000 fragments
# processed 29,500,001 fragments
# processed 30,000,000 fragments
# processed 30,500,000 fragments
# processed 31,000,000 fragments
# processed 31,500,000 fragments
# processed 32,000,000 fragments
# processed 32,500,000 fragments
# processed 33,000,000 fragments
# processed 33,500,000 fragments
# processed 34,000,000 fragments
# processed 34,500,000 fragments
# processed 35,000,000 fragments
# processed 35,500,000 fragments
# processed 36,000,000 fragments
# processed 36,500,000 fragments
# processed 37,000,000 fragments
# processed 37,500,000 fragments
# processed 38,000,000 fragments
# processed 38,500,000 fragments
# processed 39,000,000 fragments
# processed 39,500,000 fragments
# processed 40,000,000 fragments
# processed 40,500,000 fragments
# processed 41,000,000 fragments
# processed 41,500,000 fragments
# processed 42,000,000 fragments
# processed 42,500,000 fragments
# processed 43,000,000 fragments
# processed 43,500,000 fragments
# processed 44,000,000 fragments
# processed 44,500,000 fragments
# processed 45,000,000 fragments
# processed 45,500,000 fragments
# processed 46,000,000 fragments
# processed 46,500,000 fragments
# processed 47,000,000 fragments
# processed 47,500,000 fragments
# processed 48,000,000 fragments
# processed 48,500,000 fragments
# processed 49,000,000 fragments
# processed 49,500,000 fragments
# processed 50,000,000 fragments
# processed 50,500,000 fragments
# processed 51,000,000 fragments
# processed 51,500,001 fragments
# processed 52,000,000 fragments
# processed 52,500,000 fragments
# processed 53,000,000 fragments
# processed 53,500,000 fragments
# processed 54,000,000 fragments
# processed 54,500,000 fragments
# processed 55,000,000 fragments
# processed 55,500,000 fragments
# processed 56,000,000 fragments
# processed 56,500,000 fragments
# processed 57,000,000 fragments
# processed 57,500,000 fragments
# processed 58,000,000 fragments
# processed 58,500,000 fragments
# processed 59,000,000 fragments
# processed 59,500,000 fragments
# processed 60,000,000 fragments
# hits: 192,715,574, hits per frag:  3.22057
#
#
#
#
#
#
#
# [2021-03-07 22:21:22.266] [jointLog] [info] Computed 672,319 rich equivalence classes for further processing
# [2021-03-07 22:21:22.266] [jointLog] [info] Counted 52,479,650 total reads in the equivalence classes
# [2021-03-07 22:21:22.306] [jointLog] [info] Number of mappings discarded because of alignment score : 49,011,179
# [2021-03-07 22:21:22.306] [jointLog] [info] Number of fragments entirely discarded because of alignment score : 3,090,020
# [2021-03-07 22:21:22.306] [jointLog] [info] Number of fragments discarded because they are best-mapped to decoys : 0
# [2021-03-07 22:21:22.306] [jointLog] [info] Number of fragments discarded because they have only dovetail (discordant) mappings to valid targets : 1,307,014
# [2021-03-07 22:21:22.306] [jointLog] [info] Mapping rate = 87.3871%
#
# [2021-03-07 22:21:22.306] [jointLog] [info] finished quantifyLibrary()
# [2021-03-07 22:21:22.311] [jointLog] [info] Starting optimizer
# [2021-03-07 22:21:30.107] [jointLog] [info] Marked 0 weighted equivalence classes as degenerate
# [2021-03-07 22:21:30.150] [jointLog] [info] iteration = 0 | max rel diff. = 36.9922
# [2021-03-07 22:21:34.371] [jointLog] [info] iteration = 100 | max rel diff. = 19.8929
# [2021-03-07 22:21:38.599] [jointLog] [info] iteration = 200 | max rel diff. = 14.9128
# [2021-03-07 22:21:42.832] [jointLog] [info] iteration = 300 | max rel diff. = 8.72164
# [2021-03-07 22:21:47.042] [jointLog] [info] iteration = 400 | max rel diff. = 2.62871
# [2021-03-07 22:21:51.267] [jointLog] [info] iteration = 500 | max rel diff. = 0.669308
# [2021-03-07 22:21:55.485] [jointLog] [info] iteration = 600 | max rel diff. = 2.95945
# [2021-03-07 22:21:59.713] [jointLog] [info] iteration = 700 | max rel diff. = 2.20457
# [2021-03-07 22:22:03.930] [jointLog] [info] iteration = 800 | max rel diff. = 1.62651
# [2021-03-07 22:22:08.149] [jointLog] [info] iteration = 900 | max rel diff. = 0.402432
# [2021-03-07 22:22:12.363] [jointLog] [info] iteration = 1,000 | max rel diff. = 1.97006
# [2021-03-07 22:22:16.587] [jointLog] [info] iteration = 1,100 | max rel diff. = 0.87092
# [2021-03-07 22:22:20.796] [jointLog] [info] iteration = 1,200 | max rel diff. = 0.110939
# [2021-03-07 22:22:25.006] [jointLog] [info] iteration = 1,300 | max rel diff. = 0.0422752
# [2021-03-07 22:22:29.221] [jointLog] [info] iteration = 1,400 | max rel diff. = 3.74658
# [2021-03-07 22:22:33.445] [jointLog] [info] iteration = 1,500 | max rel diff. = 0.0396368
# [2021-03-07 22:22:37.655] [jointLog] [info] iteration = 1,600 | max rel diff. = 0.0939726
# [2021-03-07 22:22:41.870] [jointLog] [info] iteration = 1,700 | max rel diff. = 0.684827
# [2021-03-07 22:22:46.095] [jointLog] [info] iteration = 1,800 | max rel diff. = 0.87815
# [2021-03-07 22:22:50.303] [jointLog] [info] iteration = 1,900 | max rel diff. = 0.0319234
# [2021-03-07 22:22:54.514] [jointLog] [info] iteration = 2,000 | max rel diff. = 0.052428
# [2021-03-07 22:22:58.743] [jointLog] [info] iteration = 2,100 | max rel diff. = 0.0175536
# [2021-03-07 22:23:02.573] [jointLog] [info] iteration = 2,192 | max rel diff. = 0.00844275
# [2021-03-07 22:23:02.623] [jointLog] [info] Finished optimizer
# [2021-03-07 22:23:02.623] [jointLog] [info] writing output
#
#
# real	11m18.785s
# user	43m11.524s
# sys	0m17.605s
